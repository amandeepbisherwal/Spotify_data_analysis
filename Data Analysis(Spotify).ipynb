# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Uploading the dataset

# %%
spotify_tracks = pd.read_csv('SpotifyFeatures.csv')
spotify_artist = pd.read_csv('artists.csv')

# %% [markdown]
# ## Checking the dataset

# %%
spotify_tracks
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
spotify_tracks.shape
# Out:
# (232725, 18)

# %%
spotify_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %% [markdown]
# ## Checking the null values

# %%
spotify_tracks.isnull()
# Out:
#         genre  artist_name  track_name  track_id  popularity  acousticness  \
# 0       False        False       False     False       False         False
# 1       False        False       False     False       False         False
# 2       False        False       False     False       False         False
# 3       False        False       False     False       False         False
# 4       False        False       False     False       False         False
# ...       ...          ...         ...       ...         ...           ...
# 232720  False        False       False     False       False         False
# 232721  False        False       False     False       False         False
# 232722  False        False       False     False       False         False
# 232723  False        False       False     False       False         False
# 232724  False        False       False     False       False         False
#
# ...

# %%
spotify_tracks.isnull().sum()
# Out:
# genre               0
# artist_name         0
# track_name          1
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %% [markdown]
# ## Removing null values

# %%
spotify_tracks.dropna()
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %% [markdown]
# ## To save the removing changes

# %%
spotify_tracks.dropna(inplace = True)

# %%
spotify_artist
# Out:
#                              id  followers                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                     []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                     []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                     []
# ...                         ...        ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB     3345.0                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2       26.0                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB      406.0                     []
# 1104348  5m0Y4WSYyai2BU752lCASy      146.0                     []
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# ...

# %%
spotify_artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104349 entries, 0 to 1104348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1104349 non-null  object
#  1   followers   1104336 non-null  float64
#  2   genres      1104349 non-null  object
#  3   name        1104346 non-null  object
#  4   popularity  1104349 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 42.1+ MB

# %%
spotify_artist.isnull().sum()
# Out:
# id             0
# followers     13
# genres         0
# name           3
# popularity     0
# dtype: int64

# %%
spotofy_artist.dropna(inplace = True)

# %% [markdown]
# ## Descriptive statistical data analysis

# %%
spotify_tracks.describe().transpose()
# Out:
#                      count           mean            std          min  \
# popularity        232725.0      41.127502      18.189948      0.00000
# acousticness      232725.0       0.368560       0.354768      0.00000
# danceability      232725.0       0.554364       0.185608      0.05690
# duration_ms       232725.0  235122.339306  118935.909299  15387.00000
# energy            232725.0       0.570958       0.263456      0.00002
# instrumentalness  232725.0       0.148301       0.302768      0.00000
# liveness          232725.0       0.215009       0.198273      0.00967
# loudness          232725.0      -9.569885       5.998204    -52.45700
# speechiness       232725.0       0.120765       0.185518      0.02220
# tempo             232725.0     117.666585      30.898907     30.37900
# valence           232725.0       0.454917       0.260065      0.00000
#
#                           25%            50%          75%          max
# ...

# %%
spotify_artist.describe().transpose()
# Out:
#                 count          mean            std  min   25%   50%    75%  \
# followers   1104336.0  10743.044390  260955.390959  0.0  10.0  59.0  451.0
# popularity  1104349.0      9.083884      13.763096  0.0   0.0   2.0   14.0
#
#                    max
# followers   78900234.0
# popularity       100.0

# %% [markdown]
# ##### this .describe() gives only the statistical data on numerical values

# %%
spotify_tracks.describe(include = object).transpose()
# Out:
#                  count  unique                     top    freq
# genre           232725      27                  Comedy    9681
# artist_name     232725   14564          Giuseppe Verdi    1394
# track_name      232724  148614                    Home     100
# track_id        232725  176774  3R73Y7X53MIQZWnKloWq5i       8
# key             232725      12                       C   27583
# mode            232725       2                   Major  151744
# time_signature  232725       5                     4/4  200760

# %%
spotify_artist.describe(include = object).transpose()
# Out:
#           count   unique                     top    freq
# id      1104349  1104349  0DheY5irMjBUeLybbCUEZ2       1
# genres  1104349    48788                      []  805733
# name    1104346  1078659                     Ace      12

# %% [markdown]
# ##### .describe(include = object) gives the statistical data on 'object' data types present in the data set.

# %%
top_10_most_popular_songs = spotify_tracks.query('popularity>90', inplace = False).sort_values(by = 'popularity', ascending = False)
top_10_most_popular_songs
# Out:
#         genre             artist_name  \
# 107804    Pop           Ariana Grande
# 9027    Dance           Ariana Grande
# 9026    Dance           Ariana Grande
# 86951     Rap             Post Malone
# 107803    Pop             Post Malone
# ...       ...                     ...
# 107826    Pop                 Cardi B
# 86962     Rap  A Boogie Wit da Hoodie
# 9030    Dance           Ariana Grande
# 86960     Rap              Juice WRLD
# 9032    Dance           Ariana Grande
#
#                                       track_name                track_id  \
# 107804                                   7 rings  14msK75pk3pA33pzPVNtBF
# 9027                                     7 rings  14msK75pk3pA33pzPVNtBF
# 9026    break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 86951                                       Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107803                                      Wow.  6MWtB6iiXyIwun0YzU6DFP
# ...

# %% [markdown]
# ### Changing the duration_ms to durations in seconds.

# %%
spotify_tracks['duration'] = spotify_tracks['duration_ms'].apply(lambda x : round(x/1000))
spotify_tracks['duration_ms'].drop('duration_ms', axis = 1, inplace = False)
spotify_tracks.duration().head()

# %% [markdown]
# ## Data visualization and analysis
# ### 1. Top 5 Genres

# %%
spotify_genre = spotify_tracks.groupby('genre')['popularity'].sum().sort_values(ascending = False)
spotify_genre
spotify_genre_records = spotify_genre.head(10)
spotify_genre_records
# Out:
# genre
# Pop                 625020
# Rap                 558848
# Rock                552791
# Hip-Hop             543043
# Indie               522017
# Children’s Music    511226
# Dance               498352
# R&B                 470360
# Alternative         465127
# Folk                464394
# Name: popularity, dtype: int64

# %%
plt.figure(figsize = (7.95,7.45))
color_palette = sns.color_palette("bright")
plt.pie(spotify_genre.head(5), labels = spotify_genre.head(5))
plt.legend(spotify_genre_name)
plt.show()

# %% [markdown]
# ##### The pie chart shows the top 5 most listened genres on the spotify,
# ##### Among all the genres most listened genre is Pop followed by the others.

# %% [markdown]
# ### 2. top 10 songs by popularity

# %%
spotify_top_track_names = spotify_tracks.groupby('track_name')['popularity'].sum().sort_values(ascending = False).head(10)
spotify_top_track_names
# Out:
# track_name
# Home           4951
# You            3578
# Stay           3260
# Closer         3002
# Wake Up        2897
# Without You    2623
# Forever        2605
# Smile          2561
# Intro          2431
# Beautiful      2410
# Name: popularity, dtype: int64

# %%
plt.figure(figsize = (15,6))
spotify_top_track_names.plot.bar(color = 'mediumseagreen')
plt.legend()
plt.title('Top 10 songs by popularity', size = 15)
plt.xlabel('Songs')
plt.ylabel('Popularity count')
plt.show()

# %% [markdown]
# #### Track name "Home" is having high popularity among all songs.

# %% [markdown]
# ### 3. Bottom 10 songs on spotify

# %%
spotify_bottom_track_names = spotify_tracks.groupby('track_name')['popularity'].sum().sort_values(ascending = False).tail(10)
spotify_bottom_track_names
# Out:
# track_name
# Silent Night / Greensleeves                                    0
# Silent Night / Away in a Manger                                0
# What Kind of Mood (Am I in Today?)                             0
# What Kind of Fool am I?                                        0
# I Never Saw Another Butterfly: IV. Dusk                        0
# I Never Saw Another Butterfly: V. Campfire                     0
# What Jesus Taught                                              0
# Bhakthra Bandhu Sri Manjunatha(Folk Style Devotional Songs)    0
# Bharatbasike Nabin Mantra                                      0
# We Hymn Thee, We Bless Thee 2                                  0
# Name: popularity, dtype: int64

# %% [markdown]
# #### These are some of the least popular song on spotify

# %% [markdown]
# ### 4. Most stream artists

# %%
top_chart_artist = spotify_artist.groupby('name')['popularity'].count().sort_values(ascending=False).head()
top_chart_artist
# Out:
# name
# Rico                     12
# Ace                      12
# Forró Cintura de Mola    12
# Luna                     11
# Sun In Arms              10
# Name: popularity, dtype: int64

# %%
plt.figure(figsize = (8,5))
plt.title('Most stream artist')
top_chart_artist.plot.bar(color  = 'slategray')
plt.xlabel('Artists')
plt.ylabel('Popularity count')
plt.show()

# %% [markdown]
# #### Rico, Ace, Forrò Cintura de Mola are the most stream artists.

# %% [markdown]
# ### Artist with having highest followers on Spotify.

# %%
artist_follower = spotify_artist.groupby('name')['followers'].sum().sort_values(ascending = False).head(15)
artist_follower
# Out:
# name
# Ed Sheeran         78900234.0
# Ariana Grande      61301006.0
# Drake              54430445.0
# Justin Bieber      44606973.0
# Eminem             43747833.0
# Rihanna            42244011.0
# Billie Eilish      41792604.0
# Taylor Swift       38869193.0
# Imagine Dragons    33665795.0
# Queen              33483577.0
# Shawn Mendes       32419313.0
# Bad Bunny          32244734.0
# Post Malone        32167665.0
# BTS                31623813.0
# The Weeknd         31308207.0
# Name: followers, dtype: float64

# %%
plt.figure(figsize = (15,9))
plt.title('Most followed artist', size = 15)
artist_follower.plot.bar(color = 'forestgreen')
plt.xlabel('artists')
plt.ylabel('followers count(in millions)')
plt.show()

# %% [markdown]
# #### Ed Sheeran have the highest followers count among the top 15 top artist.
